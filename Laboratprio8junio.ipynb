# %% [markdown]
# <a href="https://colab.research.google.com/github/Luis9628/Python/blob/main/Laboratprio8junio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Laboratorio Inicial de uso de colab**

# %% [markdown]
# II Ciclo

# %% [markdown]
# Luis Aguilar Monge

# %%
import pandas as pd
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ =default()

gc=gspread.authorize(creds)
sh=gc.create('Luis Aguilar')

# %%
from gspread.utils import cell_list_to_rect
from gspread.models import Worksheet
worksheet = gc.open('Luis Aguilar').sheet1

cell_list = worksheet.range('A1:G14')

import random
for cell in cell_list:
  cell.value = random.randint(1,10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1C-TRAhxPRVAQaY46NQU6mbxDtEPllER2-I0R2rh1MJE',
#  'updatedCells': 98,
#  'updatedColumns': 7,
#  'updatedRange': "'Hoja 1'!A1:G14",
#  'updatedRows': 14}

# %%
worksheet = gc.open('Luis Aguilar').sheet1
rows=worksheet.get_all_values()
print(rows)
# Out:
# [['3', '5', '2', '4', '5', '6', '10'], ['1', '3', '3', '4', '10', '6', '8'], ['6', '1', '9', '5', '4', '3', '7'], ['7', '3', '9', '3', '5', '7', '2'], ['4', '10', '2', '7', '5', '5', '2'], ['4', '1', '7', '1', '8', '9', '10'], ['6', '7', '10', '7', '3', '9', '4'], ['8', '2', '10', '2', '2', '5', '2'], ['10', '10', '10', '1', '9', '6', '5'], ['3', '2', '2', '10', '1', '3', '5'], ['7', '6', '4', '1', '6', '9', '2'], ['5', '9', '2', '6', '1', '3', '4'], ['10', '2', '10', '7', '9', '7', '8'], ['8', '10', '10', '9', '7', '2', '2']]
